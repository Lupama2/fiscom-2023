# %% [markdown]
# #Física Computacional (Instituto Balseiro 2023)

# %% [markdown]
# ##Cátedra
# - **Profesor a Cargo**: Pablo S. Cornaglia (pablo.cornaglia@ib.edu.ar)
# - **Jefe de trabajos Prácticos**: Alexander Hernández (alexander.hernandez@ib.edu.ar)
# - **Ayudante de primera**: Sebastián Anguiano (sebastian.anguiano@ib.edu.ar)
# - **Ayudantes adscriptos (alumnos)**:
#     - Pablo Naim Chehade (pablo.chehade@ib.edu.ar)
#     - Marco Madile Hjelt (marco.madile@ib.edu.ar)
#
# ## Bibliografía
# - Notas de [Física Computacional 2022](https://drive.google.com/file/d/1Zv_vW3wvVkFlZEIgmR6r08vysiWJYUvv/view?usp=sharing) de Guillermo Abramson (Profesor del I.B.)
#     - Pueden encontrar ahí una muy buena introducción a varios de los temas que vamos a ver en la materia.
#
# - Press, William H., et al. *Numerical recipes 3rd edition: The art of scientific computing*. Cambridge university press, 2007. (*un ejemplar en la biblioteca*)
#     - Un libro clásico de métodos numéricos.
#
# - Rapaport, Dennis C. *The art of molecular dynamics simulation*. Cambridge university press, 2004. (*dos ejemplares en la biblioteca*)
#     - Un libro clásico de dinámica molecular.
# - Thijssen, Jos. *Computational physics*. Cambridge university press, 2007. (*un ejemplar en la biblioteca*)
#     - Libro muy variado de física computacional que incluye temas avanzados.
#
# - Krauth, Werner. *Statistical mechanics: algorithms and computations*. Vol. 13. OUP Oxford, 2006. (*tres ejemplares en la biblioteca*)
#     - Excelente curso de física estadística pensado desde la computación.
#     - Vamos a ver la parte del método de Montecarlo principalmente de ahí.
#     - Hay un curso online en coursera asociado a este libro (en inglés con subtítulos).
# - Landau, Rubin H., Manuel J. Páez, and Cristian C. Bordeianu. *Computational physics: Problem solving with Python*. John Wiley & Sons, 2015.
#
# - Aaronson, Scott. *Quantum computing since Democritus*. Cambridge University Press, 2013.
#     - Este se va un poco de los temas de la materia pero está muy bueno para tener una idea general de la computación clásica y cuántica.

# %% [markdown]
# ##Objetivos
# <p align = "justify">En este curso vamos a analizar una variedad de problemas de física utilizando métodos numéricos. El uso de estas herramientas nos va a permitir tratar problemas que no son resolubles analíticamente y ganar intuición física realizando "experimentos" computacionales.
#  Los problemas y métodos que vamos a ver buscan lograr desarrollar una visión amplia de la física computacional. Si bien este enfoque amplio no nos va a permitir profundizar en la justificación teórica ni en el análisis de los resultados para cada tema, nos va a dar una comprensión general de la gama de problemas que la física computacional puede resolver.<p>
#
# ###Métodos numéricos
#
# <p align = "justify">Aunque vamos a familiarizarnos con una variedad de métodos numéricos, este no es un curso específico de métodos numéricos. No vamos a poder dedicar tiempo al análisis de los métodos numéricos más comunes de integración, minimización, interpolación, transformadas integrales, etc. Estos métodos ya han sido ampliamente discutidos en la literatura y hay numerosas librerías (en FORTRAN,  C++ y Python) que los han implementado, optimizado y testeado. <p>
#
# ###Evaluación
# - Entrega de trabajos prácticos resueltos incluyendo el código utilizado. Se tendrá en cuenta la [claridad de la presentación](https://drive.google.com/file/d/1B6yhltn0UMZcdmdSKYfTTyMzhmYtMe5l/view?usp=sharing), la precisión de los resultados, la claridad del código (¡agregar comentarios cuando sea necesario!) y que sean entregados en tiempo y forma.
# - Presentaciones de 15 minutos de los trabajos prácticos resueltos (estrategia seguida, principales resultados, inconvenientes, etc.). Esto se hará durante la última media hora de las clases prácticas de manera rotativa y voluntaria. Estas presentaciones no tienen calificación numérica, pero se valorará positivamente la participación tanto en las presentaciones como en la discusión asociada.
# - Entrega y presentación de un de trabajo final, con
# análisis extendido y crítico de los resultados.
# - Presentación de 15 minutos (+ preguntas) del trabajo final.
# - Para aprobar la materia es necesario aprobar el trabajo final.
# - La nota final de la materia está basada en:
#     - Las notas de los trabajos prácticos, ponderadas.
#     - La nota del trabajo final.
#     - La evaluación cualitativa respecto a la participación en clase.
#
# Los códigos a presentar tienen que ser de producción propia y tienen que estar adecuadamente comentados.
#
# ### Programación
# Este no es un curso de programación y va a ser necesario tener un dominio básico de algún lenguaje. Esperamos que la experiencia ganada al hacer los trabajos prácticos les ayude a mejorar sus capacidades de programación.
#
# No es obligatorio usar un lenguaje en particular (aunque se recomienda el uso de C++, Python o Julia porque son lenguajes muy usados en ciencia, actualizados regularmente y que cuentan con una amplia gama de librerías para procesamiento de datos y cálculo numérico).
#
# Los ejemplos que vamos a ver ens las teóricas van a ser todos en Python.
#
#
# ![xkcd](https://imgs.xkcd.com/comics/python.png)

# %% [markdown]
# #Física y computación
#
# <p align = "justify">La física computacional puede ser considerada desde diferentes perspectivas. Una, que es interesante para reflexionar sobre qué tipos de problemas de física es posible resolver, es interpretar cualquier fenómeno físico como el resultado de un cómputo. Desde este enfoque, hay tres elementos principales en un problema de física: un estado inicial, la evolución del sistema y el estado final que se mide. En el contexto de la computación clásica, estos corresponden a la entrada (input), que se codifica como una cadena de bits (0 o 1), una serie de compuertas lógicas (el cálculo) y la salida, que también se codifica como una cadena de bits. <p>
#
# ![Física como un cómputo](https://drive.google.com/uc?export=view&id=1dy4BTSjViOVuVkhFkQ4bqifcxh-yBkaz)
#
# <p align = "justify">Nos podemos preguntar si esta perspectiva va más allá de ser una simple analogía y si es posible resolver cualquier problema de física usando una computadora clásica digital, dado que sabemos que el mundo es analógico y cuántico. La respuesta es que sí es posible (al menos en teoría). Las computadoras que utilizamos son computadoras universales, lo que significa que, con suficiente tiempo y memoria, pueden resolver cualquier problema con la precisión que se desee (siempre y cuando este problema no sea intrínsecamente insoluble). Si un problema tiene solución, se puede resolver con una computadora clásica.
# En la práctica, el uso de una computadora clásica puede resultar ineficiente para ciertos problemas, como los que involucran sistemas cuánticos complejos. Por eso se están desarrollando nuevas técnicas de computación cuántica que pueden ser más eficientes para resolver este tipo de problemas. Esto se basa en la idea original de Feynmann de realizar simulaciones cuánticas (usar un sistema cuántico que podemos controlar con precisión para simular otro). Esta es una forma de computación en la que las leyes de evolución son cuánticas. <p>

# %% [markdown]
# #Computación y Física
#
# Más allá de la analogía entre física y computación, la computación es una herramienta esencial en la física moderna.
#
# Se la usa en:
#
# - Simulaciones: se puede codificar un sistema físico, como partículas e interacciones, y aplicar la dinámica del sistema (ecuaciones de movimiento) para calcular propiedades del sistema, como la presión y la temperatura.
# - Resolución de sistemas de ecuaciones: por ejemplo las ecuaciones de Maxwell con ciertas condiciones de contorno.
# - Problemas de autovalores y autovectores: estos problemas son importantes en muchos aspectos de la física, incluyendo la mecánica cuántica.
# - Problemas de optimización: minimización de la energía o la búsqueda de soluciones.
# - Cálculos analíticos con librerías que permiten hacer cálculos simbólicos.
# - Minería de datos: es el proceso de extraer información útil de grandes volúmenes de datos, utilizando métodos de inteligencia artificial o aprendizaje automático. Puede ayudar a descubrir patrones y relaciones en los datos experimentales, teóricos o simulados.
# - Adquisición de datos: la computación también se utiliza para adquirir y procesar datos experimentales.
# - Procesamiento de datos experimentales: los datos obtenidos a partir de experimentos pueden ser analizados utilizando herramientas computacionales para extraer información relevante y hacer predicciones.
#
# <p align = "justify">Las computadoras permiten ampliar enormemente la variedad de sistemas que se pueden estudiar (las soluciones analíticas son muy poco frecuentes). La posibilidad de usar la computadora como un laboratorio numérico y de visualizar las soluciones permite desarrollar la intuición física. Hace posible acceder a soluciones de modelos que capturan la física interesante o universal de un problema. Esos modelos son muchas veces demasiado complicados para un cálculo analítico pero omiten detalles que no son esenciales para entender el problema. <p>
#
# <p align = "justify">
# La física computacional tiene un papel crucial en la retroalimentación entre la física experimental y la física teórica. La física teórica se basa muchas veces en supuestos y modelos que no siempre se corresponden con la realidad experimental. Por otro lado, la física experimental genera datos que pueden ser difíciles de interpretar sin la ayuda de herramientas teóricas.
# <p>
# <p align = "justify">
# La física computacional puede llenar esta brecha. Los modelos teóricos pueden ser simulados y comparados con los datos experimentales para verificar su validez, analizar las aproximaciones realizadas y hacer predicciones para futuros experimentos. Por otro lado, los datos experimentales pueden ser analizados con la ayuda de herramientas computacionales para extraer información relevante y compararla con las predicciones teóricas. <p>
#
# ![Fiscom](https://drive.google.com/uc?export=view&id=13RpBjqnvEmKEFVsD8W1hFkh-CRnwpk1A)
#
# Cada vez es más frecuente la reutilización de códigos. Si un grupo de investigadores desarrolla un código numérico y lo documenta adecuadamente, muchas veces distribuye una versión del código (por ejemplo en GitHub) y publica un artículo explicándolo. Otros investigadores pueden usar, y en general modificar el código, siempre y cuando citen la fuente.
#
# Los beneficios de la reutilización de códigos son claros:
# - Ahorro de tiempo y recursos: No hay que "reinventar la rueda" cada vez que se necesita resolver un problema.
#
# - Replicabilidad: otros pueden usarlo para replicar resultados y controlar que sean correctos.
#
# - Transparencia: permite una mejor comprensión y transparencia de los métodos y técnicas utilizados.
#
# - Colaboración: se incentiva la colaboración entre investigadores y el avance de la ciencia en general.
#
# - Impacto: Los investigadores que comparten sus códigos muchas veces obtienen un mayor reconocimiento y citaciones.

# %% [markdown]
# ## Google Collabs

# %% [markdown]
# Para las clases y las prácticas vamos a usar la plataforma [Google Collabs](https://colab.research.google.com/notebooks/intro.ipynb).
# Es una plataforma tiene muchas ventajas:
# * Se puede escribir en LaTeX por lo que van a poder hacer los informes ahí, si así lo desean.
# * Se pueden ejecutar programas en Python y hacer figuras.
# * Tiene las librerías más comunes y útiles para cálculo numérico (y simbólico) preinstaladas (```numpy```, ```sympy```, etc.), pero es posible instalar nuevas si hace falta.
# * Pueden usar Google drive para leer y guardar datos.
# * Tiene acceso a tiempo de cálculo en *CPUs* y *GPUs*.
# * Tiene control de cambios (no hace falta usar ```git```)
# * Es ideal para colaborar (al menos para proyectos no muy extensos).
# * etc.
#
# Las principales desventajas que tiene son tres:
# * Está pensada para programar en Python.
# * Para cálculos muy prolongados hace falta pagar.
# * Hay que tener acceso a Internet.
#
# Para cálculos prolongados van a poder usar el cluster de la Gerencia de física (tiene unos 750 cores de CPU y GPUs disponibles). (Hablar con @AlexanderHernández)

# %% [markdown]
# #*chatGPT*, *copilot* y otras variantes de inteligencia artificial

# %% [markdown]
# Las inteligencias artificiales (IA) pueden servir como un asistente personal que les permita aumentar la productividad.
# Pueden ser muy útiles en esta materia para:
# * Encontrar errores en un código.
# * Dar ejemplos y explicar cómo se utilizan algunas librerías.
# * Agregar comentarios a un código y reformatearlo para hacerlo más claro o más sencillo.
#
# Como cualquier información de otra fuente (Internet, Wikipedia, un artículo científico, un libro, un profesor), tiene alguna probabilidad de ser incorrecta (bastante alta en el caso de las IA actuales). Hay que usarlas con pesamiento crítico y (con las IA actuales) verificando con otras fuentes.
#
# Que no les pase como a [Steven Schwartz](https://www.clarin.com/internacional/unidos-abogado-debio-disculparse-presentar-antecedentes-falsos-creados-chatgpt-podria-recibir-dura-sancion_0_hf500FslVs.html)...
#
# Les sugiero que escriban primero una versión del código antes de eventualmente usar la IA para resolver problemas. Si la IA escribe una parte del código, asegúrense de que lo entienden (le pueden pedir que lo explique...) y que está haciendo lo que necesitan que haga. Eso les va a permitir modificar el código, solucionar problemas y adaptarlo a situaciones diferentes.
#
# Espero que aprovechen esta materia para mejorar sus capacidades de programación, pensamiento crítico, entendimiento de la física y conocimiento de las posibilidades que ofrece la física computacional.
# La forma de lograrlo es enfrentándose a los problemas de las prácticas e interactuando con la cátedra y sus compañeros y compañeras.
#
# Si usan una IA para sus trabajo les pido que lo indiquen. Es parte de la ética profesional citar las fuentes.
#
# Les paso algunas citas sobre "aprender y hacer" (generadas por chatGPT, así que pueden ser apócrifas... :-))
#
# * "Oigo y olvido. Veo y recuerdo. Hago y entiendo." - Confucio
#
# * "Dime y lo olvido, enséñame y lo recuerdo, involúcrame y lo aprendo." - Benjamin Franklin
#
# * "Los errores son las puertas del descubrimiento." - James Joyce
#
# * "La única manera de hacer un gran trabajo es amar lo que haces." - Steve Jobs
#
# * "Aprende todo lo que puedas, cuando puedas, de quien puedas; siempre llegará el momento en que estarás agradecido de haberlo hecho." - Sarah Caldwell
#
# * "Aprendemos más buscando la respuesta a una pregunta y no encontrándola, que aprendiendo la respuesta en sí misma." - Lloyd Alexander
